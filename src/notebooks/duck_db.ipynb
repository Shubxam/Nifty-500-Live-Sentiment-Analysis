# %%
import duckdb as ddb
import pandas as pd

# %%
import os
import sys

# This adds the 'src' directory to the Python path.
src_rel_path = '../src'
src_abs_path = os.path.abspath(src_rel_path)

if src_abs_path not in sys.path:
    sys.path.append(src_abs_path)
    print(f"Added '{src_abs_path}' to sys.path")
else:
    print(f"'{src_abs_path}' is already in sys.path")
# Out:
# '/Users/shubxam/Code/Nifty-500-Live-Sentiment-Analysis/src' is already in sys.path

# %% [markdown]
# ## check primary key constraints in tables

# %%
con = ddb.connect('../datasets/ticker_data.db')

# %%
con.execute(
    "SELECT constraint_name FROM information_schema.table_constraints WHERE table_name = 'article_data' AND constraint_type = 'PRIMARY KEY'"
).fetch_df()
# Out:
#                      constraint_name
# 0  article_data_ticker_headline_pkey

# %%
# drop the primary key constraint
con.execute(
    'ALTER TABLE article_data DROP CONSTRAINT IF EXISTS article_data_ticker_headline_date_posted_pkey;'
).fetch_df()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedException                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 con.execute("ALTER TABLE article_data DROP CONSTRAINT IF EXISTS article_data_ticker_headline_date_posted_pkey;").fetch_df()
#
# NotImplementedException: Not implemented Error: No support for that ALTER TABLE option yet!

# %%
# add the new primary key constraint
con.execute('ALTER TABLE article_data ADD PRIMARY KEY (ticker, headline);')

# %%
# commit the changes
con.commit()

# %%
con.close()

# %% [markdown]
# ## compute sentiment scores for all articles in db

# %%
import duckdb as ddb

# %%
db_path = '../datasets/ticker_data.db'
conn = ddb.connect(db_path)

# %%
articles = conn.execute('select ticker, headline from article_data_temp').fetch_df()
articles.__len__()

# %%
from tqdm import tqdm
from transformers.models.bert import BertForSequenceClassification, BertTokenizer
from transformers.pipelines import pipeline

# %%
headlines = articles.headline.tolist()

# %%
finbert_1 = BertForSequenceClassification.from_pretrained(
    'yiyanghkust/finbert-tone',
    num_labels=3,
    use_safetensors=True,  # Use safe tensors
)

tokenizer_1 = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')

# set top_k=1 to get the most likely label or top_k=None to get all labels
# device=-1 means CPU
nlp_1 = pipeline(
    'sentiment-analysis',
    model=finbert_1,
    tokenizer=tokenizer_1,
    device='mps',
    top_k=None,
    framework='pt',
)
# Out:
# Device set to use mps

# %%
results = nlp_1(headlines, batch_size=2048)

# %%
flattened_data: list[dict[str, float]] = []

for news_item_sentiment_list in tqdm(iterable=results, desc='Processing Sentiment'):
    news_item_sentiment_dict = {}
    for individual_label_dict in news_item_sentiment_list:
        news_item_sentiment_dict[individual_label_dict['label']] = (
            individual_label_dict['score']
        )
    flattened_data.append(news_item_sentiment_dict)
# Out:
# Processing Sentiment: 100%|██████████| 14623/14623 [00:00<00:00, 411508.65it/s]
# Processing Sentiment: 100%|██████████| 14623/14623 [00:00<00:00, 411508.65it/s]

# %%
df = pd.DataFrame(flattened_data)
df.fillna(0, inplace=True)  # Fill NaN values with 0

# %%
df = df.astype(
    {
        'Positive': 'float32',
        'Neutral': 'float32',
        'Negative': 'float32',
    }
)

# %%
df
# Out:
#         Neutral  Negative      Positive
# 0      0.999082  0.000854  6.357017e-05
# 1      0.897181  0.097918  4.900872e-03
# 2      0.999982  0.000017  4.303088e-07
# 3      0.999265  0.000711  2.424426e-05
# 4      0.999359  0.000159  4.819799e-04
# ...         ...       ...           ...
# 14618  0.996375  0.003199  4.263582e-04
# 14619  0.000017  0.000005  9.999781e-01
# 14620  0.999989  0.000008  2.886356e-06
# 14621  0.999980  0.000009  1.117425e-05
# 14622  0.000002  0.999981  1.763398e-05
#
# [14623 rows x 3 columns]

# %% [markdown]
# ## merge the sentiment data with the original articles dataframe

# %%
df = pd.merge(
    articles,
    df,
    left_index=True,
    right_index=True,
)

# %%
df.loc[:, 'compound'] = (
    df.loc[:, 'Positive']
    .where(df['Positive'] > df['Negative'], -df['Negative'])
    .astype(float)
    .round(4)
)

# %%
df.rename(
    columns={
        'Positive': 'positive_sentiment',
        'Negative': 'negative_sentiment',
        'Neutral': 'neutral_sentiment',
        'compound': 'compound_sentiment',
    },
    inplace=True,
)

# %%
df
# Out:
#            ticker                                           headline  \
# 0        ADANIENT  Top Gainers and Losers today on 28 August, 202...
# 1        ADANIENT  6 Adani stocks, LIC, and 3 PSUs slip below 20 ...
# 2        ADANIENT  Adani Group invests Rs 2,000 crore in Dharavi ...
# 3        ADANIENT  Adani’s airport business to undergo de-merger ...
# 4        ADANIENT  Adani Ports acquires 80% stake in global OSV o...
# ...           ...                                                ...
# 14618       TECHM                                  Tech Mahindra Ltd
# 14619       TITAN  Best Premium Wrist Watches: The Timekeepers Of...
# 14620  ULTRACEMCO  Stocks to watch: Infosys, Jio Financial, Ultra...
# 14621       WIPRO  Wipro announces results for the Quarter and Ye...
# 14622       WIPRO  Indian shares open lower, dragged by IT on Wip...
#
#        neutral_sentiment  negative_sentiment  positive_sentiment  \
# 0               0.999082            0.000854        6.357017e-05
# 1               0.897181            0.097918        4.900872e-03
# 2               0.999982            0.000017        4.303088e-07
# 3               0.999265            0.000711        2.424426e-05
# 4               0.999359            0.000159        4.819799e-04
# ...                  ...                 ...                 ...
# 14618           0.996375            0.003199        4.263582e-04
# 14619           0.000017            0.000005        9.999781e-01
# 14620           0.999989            0.000008        2.886356e-06
# 14621           0.999980            0.000009        1.117425e-05
# 14622           0.000002            0.999981        1.763398e-05
#
#        compound_sentiment
# 0                 -0.0009
# 1                 -0.0979
# 2                 -0.0000
# 3                 -0.0007
# 4                  0.0005
# ...                   ...
# 14618             -0.0032
# 14619              1.0000
# 14620             -0.0000
# 14621              0.0000
# 14622             -1.0000
#
# [14623 rows x 6 columns]

# %% [markdown]
# ## update the article_data table with the new sentiment data

# %%
conn.register('df_virtual', df)

# %%
query = """
SELECT 
  adt.ticker, 
  adt.headline, 
  adt.date_posted, 
  adt.source, 
  adt.article_link, 
  dfv.neutral_sentiment, 
  dfv.negative_sentiment, 
  dfv.positive_sentiment, 
  dfv.compound_sentiment, 
  adt.created_at
FROM article_data_temp adt
INNER JOIN df_virtual dfv ON adt.ticker = dfv.ticker
                     AND adt.headline = dfv.headline;
"""

# %%
merged_df_from_duckdb = conn.execute(query).fetchdf()

# %%
merged_df_from_duckdb
# Out:
#            ticker                                           headline  \
# 0        ADANIENT  Top Gainers and Losers today on 28 August, 202...
# 1        ADANIENT  6 Adani stocks, LIC, and 3 PSUs slip below 20 ...
# 2        ADANIENT  Adani Group invests Rs 2,000 crore in Dharavi ...
# 3        ADANIENT  Adani’s airport business to undergo de-merger ...
# 4        ADANIENT  Adani Ports acquires 80% stake in global OSV o...
# ...           ...                                                ...
# 14618       TECHM                                  Tech Mahindra Ltd
# 14619       TITAN  Best Premium Wrist Watches: The Timekeepers Of...
# 14620  ULTRACEMCO  Stocks to watch: Infosys, Jio Financial, Ultra...
# 14621       WIPRO  Wipro announces results for the Quarter and Ye...
# 14622       WIPRO  Indian shares open lower, dragged by IT on Wip...
#
#                date_posted                 source  \
# 0      2024-08-29 01:30:14               Livemint
# 1      2024-08-29 01:30:14     The Economic Times
# 2      2024-08-30 11:30:14      Business Standard
# 3      2024-08-30 01:30:14         Times of India
# 4      2024-08-30 15:30:14  The Financial Express
# ...                    ...                    ...
# 14618  2024-04-19 11:35:30      Business Standard
# 14619  2025-04-19 05:35:30         Jagran English
# 14620  2025-04-17 11:35:31                   Mint
# 14621  2025-04-05 11:35:31                  Wipro
# 14622  2025-04-17 11:35:31            TradingView
#
#                                             article_link  neutral_sentiment  \
# 0      https://www.livemint.com/market/stock-market-n...           0.999082
# 1      https://m.economictimes.com/markets/stocks/new...           0.897181
# 2      https://www.business-standard.com/companies/ne...           0.999982
# 3      https://timesofindia.indiatimes.com/business/i...           0.999265
# 4      https://www.financialexpress.com/business/indu...           0.999359
# ...                                                  ...                ...
# 14618  https://www.business-standard.com/markets/tech...           0.996375
# 14619  https://english.jagran.com/smart-guide/style-v...           0.000017
# 14620  https://www.livemint.com/market/stock-market-n...           0.999989
# 14621  https://www.wipro.com/newsroom/press-releases/...           0.999980
# 14622  https://www.tradingview.com/news/reuters.com,2...           0.000002
#
#        negative_sentiment  positive_sentiment  compound_sentiment  \
# 0                0.000854        6.357017e-05             -0.0009
# 1                0.097918        4.900872e-03             -0.0979
# 2                0.000017        4.303088e-07             -0.0000
# 3                0.000711        2.424426e-05             -0.0007
# 4                0.000159        4.819799e-04              0.0005
# ...                   ...                 ...                 ...
# 14618            0.003199        4.263582e-04             -0.0032
# 14619            0.000005        9.999781e-01              1.0000
# 14620            0.000008        2.886356e-06             -0.0000
# 14621            0.000009        1.117425e-05              0.0000
# 14622            0.999981        1.763398e-05             -1.0000
#
#                    created_at
# 0     2024-08-31 01:30:45.048
# 1     2024-08-31 01:30:45.048
# 2     2024-08-31 01:30:45.048
# 3     2024-08-31 01:30:45.048
# 4     2024-08-31 01:30:45.048
# ...                       ...
# 14618 2025-04-19 11:35:50.926
# 14619 2025-04-19 11:35:50.926
# 14620 2025-04-19 11:35:50.926
# 14621 2025-04-19 11:35:50.926
# 14622 2025-04-19 11:35:50.926
#
# [14623 rows x 10 columns]

# %%
conn.sql(
    'CREATE OR REPLACE TABLE article_data_temp AS SELECT * FROM merged_df_from_duckdb;'
)

# %%
conn.execute('SELECT * FROM article_data_temp LIMIT 5').fetch_df()
# Out:
#      ticker                                           headline  \
# 0  ADANIENT  Top Gainers and Losers today on 28 August, 202...
# 1  ADANIENT  6 Adani stocks, LIC, and 3 PSUs slip below 20 ...
# 2  ADANIENT  Adani Group invests Rs 2,000 crore in Dharavi ...
# 3  ADANIENT  Adani’s airport business to undergo de-merger ...
# 4  ADANIENT  Adani Ports acquires 80% stake in global OSV o...
#
#            date_posted                 source  \
# 0  2024-08-29 01:30:14               Livemint
# 1  2024-08-29 01:30:14     The Economic Times
# 2  2024-08-30 11:30:14      Business Standard
# 3  2024-08-30 01:30:14         Times of India
# 4  2024-08-30 15:30:14  The Financial Express
#
#                                         article_link  neutral_sentiment  \
# 0  https://www.livemint.com/market/stock-market-n...           0.999082
# 1  https://m.economictimes.com/markets/stocks/new...           0.897181
# 2  https://www.business-standard.com/companies/ne...           0.999982
# 3  https://timesofindia.indiatimes.com/business/i...           0.999265
# 4  https://www.financialexpress.com/business/indu...           0.999359
#
#    negative_sentiment  positive_sentiment  compound_sentiment  \
# 0            0.000854        6.357017e-05             -0.0009
# 1            0.097918        4.900872e-03             -0.0979
# 2            0.000017        4.303088e-07             -0.0000
# 3            0.000711        2.424426e-05             -0.0007
# 4            0.000159        4.819799e-04              0.0005
#
#                created_at
# 0 2024-08-31 01:30:45.048
# 1 2024-08-31 01:30:45.048
# 2 2024-08-31 01:30:45.048
# 3 2024-08-31 01:30:45.048
# 4 2024-08-31 01:30:45.048

# %%
conn.close()

# %% [markdown]
# # adding existing data to table to check upsert operation

# %%
import pandas as pd

from database import DatabaseManager

# %%
dbm = DatabaseManager()

# %%
articles = dbm.get_articles()
articles.drop(columns=['created_at'], inplace=True)
articles.head()
# Out:
#      ticker                                           headline  \
# 0  HDFCBANK  HDFC Bank Q4 Results Live: Profit seen up 3.3%...
# 1      ONGC  Market Focus Still On Tariffs; Tesla Leads Key...
# 2  RELIANCE  Jio Financial Share Price: Q4 Results 2025 Out...
# 3    JIOFIN  Jio Financial Share Price: Q4 Results 2025 Out...
# 4  RELIANCE  Jio Financial Services: FY 2025 dividend incom...
#
#            date_posted                     source  \
# 0  2025-04-19 11:32:21                  CNBC TV18
# 1  2025-04-19 11:15:26  Investor's Business Daily
# 2  2025-04-19 08:35:27             Jobaaj Stories
# 3  2025-04-19 08:35:24             Jobaaj Stories
# 4  2025-04-19 07:35:27                     ET Now
#
#                                         article_link  neutral_sentiment  \
# 0  https://www.cnbctv18.com/market/hdfc-bank-q4-r...           0.000025
# 1  https://www.investors.com/market-trend/stock-m...           0.989872
# 2  https://stories.jobaaj.com/news-updates/market...           0.999996
# 3  https://stories.jobaaj.com/news-updates/market...           0.999996
# 4  https://www.etnownews.com/markets/jio-financia...           0.999993
#
#    negative_sentiment  positive_sentiment  compound_sentiment
# 0        9.484177e-07        9.999737e-01              1.0000
# 1        2.959660e-03        7.168587e-03              0.0072
# 2        2.762954e-06        1.634307e-06             -0.0000
# 3        2.762954e-06        1.634307e-06             -0.0000
# 4        6.710098e-06        2.585766e-07             -0.0000

# %%
dbm.insert_articles(articles, has_sentiment=True)
# Out:
# 2025-04-21 23:53:18.854 | INFO     | database:insert_articles:141 - Inserting articles with sentiment scores for 20 news articles

# %%
articles = dbm.get_articles(n=21)
articles
# Out:
#         ticker                                           headline  \
# 0     HDFCBANK  HDFC Bank Q4 Results Live: Profit seen up 3.3%...
# 1         ONGC  Market Focus Still On Tariffs; Tesla Leads Key...
# 2     RELIANCE  Jio Financial Share Price: Q4 Results 2025 Out...
# 3       JIOFIN  Jio Financial Share Price: Q4 Results 2025 Out...
# 4     RELIANCE  Jio Financial Services: FY 2025 dividend incom...
# 5       JIOFIN  Jio Financial Services: FY 2025 dividend incom...
# 6      HCLTECH  Q4 Earnings Next Week: Reliance, HUL, Maruti, ...
# 7          BEL  Bharat Electronics shares get BUY call for 6 m...
# 8        TITAN  Best Premium Wrist Watches: The Timekeepers Of...
# 9     ADANIENT  Adani’s 42% Revenue Share Bid Enables Govt To ...
# 10  TATAMOTORS  Tata Motors: New record for Tata Group company...
# 11        SBIN  State Bank of India's (NSE:SBIN) five-year ear...
# 12        ONGC  This Strategist Downgraded Stocks—Again. The V...
# 13    HDFCLIFE  HDFC Life to continue to invest in expanding b...
# 14          LT  CESTAT Rules 'Business Auxiliary Service' Clas...
# 15    HDFCLIFE  HDFC Life will keep margins range bound at 25-...
# 16  BAJAJ-AUTO     ​5 Cruiser Bikes In India With Highest Mileage
# 17   COALINDIA  Coal India Share Price Target: PSU arm SECL si...
# 18        ONGC  Asian markets are mostly higher as Wall Street...
# 19        ONGC  S&P 500 ekes out a gain, Dow tumbles 500 point...
# 20      JIOFIN  Jio Financial Services Limited AUM crosses Rs....
#
#             date_posted                     source  \
# 0   2025-04-19 11:32:21                  CNBC TV18
# 1   2025-04-19 11:15:26  Investor's Business Daily
# 2   2025-04-19 08:35:27             Jobaaj Stories
# 3   2025-04-19 08:35:24             Jobaaj Stories
# 4   2025-04-19 07:35:27                     ET Now
# 5   2025-04-19 07:35:24                     ET Now
# 6   2025-04-19 07:35:20             Republic World
# 7   2025-04-19 06:35:18                     ET Now
# 8   2025-04-19 05:35:30             Jagran English
# 9   2025-04-19 05:35:14                Goodreturns
# 10  2025-04-19 02:35:29                        MSN
# 11  2025-04-19 02:35:28         Simply Wall Street
# 12  2025-04-18 18:35:26                   Barron's
# 13  2025-04-18 17:35:21               BusinessLine
# 14  2025-04-18 14:35:25                    Taxscan
# 15  2025-04-18 14:35:21          Business Standard
# 16  2025-04-18 14:35:16                  Times Now
# 17  2025-04-18 12:35:18                     ET Now
# 18  2025-04-18 11:35:26                    AP News
# 19  2025-04-18 11:35:26                       CNBC
# 20  2025-04-18 11:35:24           Deccan Chronicle
#
#                                          article_link  neutral_sentiment  \
# 0   https://www.cnbctv18.com/market/hdfc-bank-q4-r...       2.543604e-05
# 1   https://www.investors.com/market-trend/stock-m...       9.898718e-01
# 2   https://stories.jobaaj.com/news-updates/market...       9.999956e-01
# 3   https://stories.jobaaj.com/news-updates/market...       9.999956e-01
# 4   https://www.etnownews.com/markets/jio-financia...       9.999931e-01
# 5   https://www.etnownews.com/markets/jio-financia...       9.999931e-01
# 6   https://www.republicworld.com/business/q4-earn...       9.999927e-01
# 7   https://www.etnownews.com/markets/bharat-elect...       4.348312e-06
# 8   https://english.jagran.com/smart-guide/style-v...       1.689028e-05
# 9   https://www.goodreturns.in/news/adani-s-42-rev...       9.994743e-01
# 10  https://www.msn.com/en-in/autos/news/tata-moto...       3.604553e-03
# 11  https://simplywall.st/stocks/in/banks/nse-sbin...       7.296161e-07
# 12  https://www.barrons.com/articles/stock-market-...       1.073139e-03
# 13  https://www.thehindubusinessline.com/money-and...       9.980124e-01
# 14  https://www.taxscan.in/classification-of-servi...       9.999610e-01
# 15  https://www.business-standard.com/finance/inte...       9.985567e-01
# 16  https://www.timesnownews.com/web-stories/auto/...       4.104290e-07
# 17  https://www.etnownews.com/markets/coal-india-s...       7.988111e-01
# 18  https://apnews.com/article/stocks-markets-powe...       6.457435e-01
# 19  https://www.cnbc.com/2025/04/16/stock-market-t...       9.857996e-01
# 20  https://www.deccanchronicle.com/business/jio-f...       9.999982e-01
#
#     negative_sentiment  positive_sentiment  compound_sentiment  \
# 0         9.484177e-07        9.999737e-01              1.0000
# 1         2.959660e-03        7.168587e-03              0.0072
# 2         2.762954e-06        1.634307e-06             -0.0000
# 3         2.762954e-06        1.634307e-06             -0.0000
# 4         6.710098e-06        2.585766e-07             -0.0000
# 5         6.710098e-06        2.585766e-07             -0.0000
# 6         6.483144e-06        8.144183e-07             -0.0000
# 7         8.704934e-08        9.999956e-01              1.0000
# 8         4.988682e-06        9.999781e-01              1.0000
# 9         1.973229e-05        5.058589e-04              0.0005
# 10        1.088668e-06        9.963943e-01              0.9964
# 11        9.999976e-01        1.712842e-06             -1.0000
# 12        9.985177e-01        4.092259e-04             -0.9985
# 13        1.712588e-04        1.816310e-03              0.0018
# 14        3.783238e-05        1.209910e-06             -0.0000
# 15        1.414570e-03        2.877533e-05             -0.0014
# 16        1.381286e-07        9.999995e-01              1.0000
# 17        7.491915e-03        1.936970e-01              0.1937
# 18        9.429207e-02        2.599644e-01              0.2600
# 19        1.825250e-03        1.237516e-02              0.0124
# 20        1.723209e-06        7.579590e-08             -0.0000
#
#                 created_at
# 0  2025-04-21 23:53:18.855
# 1  2025-04-21 23:53:18.855
# 2  2025-04-21 23:53:18.855
# 3  2025-04-21 23:53:18.855
# 4  2025-04-21 23:53:18.855
# 5  2025-04-21 23:53:18.855
# 6  2025-04-21 23:53:18.855
# 7  2025-04-21 23:53:18.855
# 8  2025-04-21 23:53:18.855
# 9  2025-04-21 23:53:18.855
# 10 2025-04-21 23:53:18.855
# 11 2025-04-21 23:53:18.855
# 12 2025-04-21 23:53:18.855
# 13 2025-04-21 23:53:18.855
# 14 2025-04-21 23:53:18.855
# 15 2025-04-21 23:53:18.855
# 16 2025-04-21 23:53:18.855
# 17 2025-04-21 23:53:18.855
# 18 2025-04-21 23:53:18.855
# 19 2025-04-21 23:53:18.855
# 20 2025-04-19 11:35:50.926
